# %%
from braininvaders2015a.dataset import BrainInvaders2015a

# %%
dataset = BrainInvaders2015a()

# %%
data_subject1 = dataset._get_single_subject_data(2)
# Out:
# Setting non-standard config type: "MNE_DATASETS_BRAININVADERS2015A_PATH"
# c:\users\computer\bcieeg\py.bi.eeg.2015a-gipsa-master\braininvaders2015a\download.py:61: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_BRAININVADERS2015A_PATH"
#   _do_path_update(path, update_path, key, sign)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)

# %%
a = data_subject1['session_1']['run_1']
a.plot_psd()
# Out:
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# c:\Users\Computer\BCIEEG\lib\site-packages\mne\io\pick.py:282: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\Users\Computer\AppData\Local\Temp/ipykernel_7512/515335997.py:2: RuntimeWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   a.plot_psd()

# %%
# convert data to pandas dataframe
data_ses1_run1 = data_subject1['session_1']['run_1']
data_ses1_run1_pd = data_ses1_run1.to_data_frame()
print(type(data_ses1_run1_pd))
print(data_ses1_run1_pd.shape)
data_ses1_run1_pd.head()
# Out:
# Converting time column to int64...
# <class 'pandas.core.frame.DataFrame'>
# (614400, 33)
# signal           Fp1           Fp2           AFz            F7            F3  \
# time
# 0       4.351532e+10  3.374213e+09  1.860765e+10  6.971902e+09  2.982652e+10
# 2       4.355936e+10  3.360288e+09  1.860847e+10  6.976701e+09  2.985069e+10
# 4       4.353002e+10  3.365756e+09  1.860588e+10  6.946013e+09  2.984104e+10
# 6       4.357948e+10  3.369699e+09  1.861185e+10  6.962723e+09  2.986497e+10
# 8       4.360522e+10  3.378181e+09  1.862089e+10  6.978243e+09  2.988512e+10
#
# signal            F4            F8           FC5           FC1           FC2  \
# time
# 0       4.000418e+10  4.102573e+09  7.353271e+10  2.991370e+10  4.621610e+10
# 2       4.001167e+10  4.106633e+09  7.358572e+10  2.992264e+10  4.627141e+10
# 4       4.001477e+10  4.112995e+09  7.354304e+10  2.991893e+10  4.626858e+10
# 6       4.002873e+10  4.114132e+09  7.359755e+10  2.993130e+10  4.634009e+10
# 8       4.004137e+10  4.114836e+09  7.362723e+10  2.994569e+10  4.635190e+10
#
# signal   ...               P4            P8           PO7            O1  \
# time     ...
# 0        ...    -2.267728e+11  4.177480e+09  4.532820e+09  1.344360e+09
# 2        ...    -2.283555e+11  4.184700e+09  4.539590e+09  1.357497e+09
# 4        ...    -2.287586e+11  4.170051e+09  4.538542e+09  1.341858e+09
# 6        ...    -2.279367e+11  4.176898e+09  4.509156e+09  1.333889e+09
# 8        ...    -2.252675e+11  4.193741e+09  4.466426e+09  1.347239e+09
#
# signal            Oz            O2           PO8           PO9          PO10  \
# time
# 0       3.473106e+09  7.362110e+09  2.116982e+10  2.328324e+10  1.481903e+10
# 2       3.482561e+09  7.365275e+09  2.118114e+10  2.329373e+10  1.483480e+10
# 4       3.468283e+09  7.356518e+09  2.118501e+10  2.329013e+10  1.483251e+10
# 6       3.467623e+09  7.357381e+09  2.117297e+10  2.330814e+10  1.484593e+10
# 8       3.480319e+09  7.363648e+09  2.118979e+10  2.332148e+10  1.486648e+10
#
# signal  STI 014
# time
# 0           0.0
# 2           0.0
# 4           0.0
# 6           0.0
# 8           0.0
#
# [5 rows x 33 columns]
