# %% [markdown]
# ### Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Define csv path

# %%
# SVM model
path_PCA = f'results/testAccuracyNoPCA.csv'
path_noPCA = f'results/testAccuracyPCA.csv'

# %%
PCA = pd.read_csv(path_PCA)
noPCA = pd.read_csv(path_noPCA)

# %% [markdown]
# ### Show result

# %%
PCA.head()
# Out:
#    subject   acc3DCNN     accSVM  accParallel   accCMCNN
# 0        2  88.297872  80.141844    86.835106  80.851064
# 1        3  79.166667  90.740741    88.194444  93.055556
# 2        4  81.609195  95.384615    87.354651  82.558140
# 3        5  87.356322  91.538462    87.936047  81.395349
# 4        6  83.333333  83.333333    86.342593  83.333333

# %%
noPCA.head()
# Out:
#    subject   acc3DCNN     accSVM  accParallel   accCMCNN
# 0        2  91.489362  80.141844    89.306294  77.659574
# 1        3  88.888889  90.740741    95.543981  94.444444
# 2        4  88.505747  95.384615    90.782461  93.023256
# 3        5  91.954023  91.538462    91.303295  84.883721
# 4        6  80.555556  83.333333    86.530671  84.259259

# %%
plt.plot(PCA['subject'],PCA['accSVM'], '.-', label="SVM")
plt.plot(PCA['subject'],PCA['acc3DCNN'], '.-', label="3D-CNN")
plt.plot(PCA['subject'],PCA['accParallel'], '.-', label="2D-Parallel-CNN")
plt.plot(PCA['subject'],PCA['accCMCNN'], '.-', label="CM-CW-CNN")
plt.ylim(50, 100)
plt.title("Accuracy: Model with PCA")
plt.xlabel("subject")
plt.ylabel("accuracy (%)")
plt.legend()
plt.show()

# %%
plt.plot(noPCA['subject'],noPCA['accSVM'], '.-', label="SVM")
plt.plot(noPCA['subject'],noPCA['acc3DCNN'], '.-', label="3D-CNN")
plt.plot(noPCA['subject'],noPCA['accParallel'], '.-', label="2D-Parallel-CNN")
plt.plot(noPCA['subject'],noPCA['accCMCNN'], '.-', label="CM-CW-CNN")
plt.ylim(50, 100)
plt.title("Accuracy: Model without PCA")
plt.xlabel("subject")
plt.ylabel("accuracy (%)")
plt.legend()
plt.show()

# %%
plt.plot(noPCA['subject'],noPCA['accParallel'], '.-', label="no PCA")
plt.plot(PCA['subject'],PCA['accParallel'], '.-', label="PCA")
plt.ylim(50, 100)
plt.title("Accuracy: Model Parallel-CNN")
plt.xlabel("subject")
plt.ylabel("accuracy (%)")
plt.legend()
plt.show()

# %%
plt.plot(noPCA['subject'],noPCA['acc3DCNN'], '.-', label="no PCA")
plt.plot(PCA['subject'],PCA['acc3DCNN'], '.-', label="PCA")
plt.ylim(50, 100)
plt.title("Accuracy: Model 3D-CNN")
plt.xlabel("subject")
plt.ylabel("accuracy (%)")
plt.legend()
plt.show()
